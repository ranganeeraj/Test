# %% [markdown]
# <a href="https://colab.research.google.com/github/ranganeeraj/Test/blob/main/CSV_Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Link - https://github.com/adityarc19/aqi-india/blob/main/city_day.csv

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/adityarc19/aqi-india/main/city_day.csv'
df = pd.read_csv(url, header=None, sep='\n')
df = df[0].str.split(',', expand=True)
df
# Out:
#                   0           1      2      3     4      5      6      7   \
# 0               City        Date  PM2.5   PM10    NO    NO2    NOx    NH3
# 1          Ahmedabad  2015-01-01                0.92  18.22  17.15
# 2          Ahmedabad  2015-01-02                0.97  15.69  16.46
# 3          Ahmedabad  2015-01-03                17.4   19.3   29.7
# 4          Ahmedabad  2015-01-04                 1.7  18.48  17.97
# ...              ...         ...    ...    ...   ...    ...    ...    ...
# 29527  Visakhapatnam  2020-06-27  15.02  50.94  7.68  25.06  19.54  12.47
# 29528  Visakhapatnam  2020-06-28  24.38  74.09  3.42  26.06  16.53  11.99
# 29529  Visakhapatnam  2020-06-29  22.91  65.73  3.45  29.53  18.33  10.71
# 29530  Visakhapatnam  2020-06-30  16.64  49.97  4.05  29.26   18.8  10.03
# 29531  Visakhapatnam  2020-07-01   15.0   66.0   0.4  26.85  14.05    5.2
#
#          8      9       10       11       12      13    14            15
# ...
